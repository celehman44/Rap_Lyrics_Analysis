# %%
import pickle
import pandas as pd
import numpy as np
import lyricsgenius as genius
client_access_token = "OWyOJwsI5mCr4YxTeADx2ioI1zRV-A8CKUPBxo3GRIyixhVHrDgPfAknjAgwRkyy"
api = genius.Genius(client_access_token)

# %%
with open('./artist_names.pkl', 'rb') as f:
    artist_names = pickle.load(f)

# %%
def downloadLyrics(artist_names, max_songs=None):
    artist_objects = [api.search_artist(name, max_songs=max_songs) for name in artist_names]
    api.save_artists(artist_objects, overwrite=True)

# %%
downloadLyrics(artist_names)
# Out:
# Searching for songs by Eminem...
#
# Song 1: "1-833-2GET-REV (REVIVAL Voicemail)"
# Song 2: "1996 Underground Freestyle"
# Song 3: "1997 Freestyle Live at Wetlands, NYC"
# Song 4: "1997 Rap Olympics"
# Song 5: "1999"
# Song 6: "2004 Tim Westwood Freestyle"
# Song 7: "2012 Something From Nothing: Art of Rap Freestyle"
# Song 8: "2.0 Boys"
# Song 9: "25 to Life"
# Song 10: "313"
# Song 11: "3 a.m."
# Song 12: "3 Verses"
# Song 13: "4 Verses"
# Song 14: "50 Ways"
# Song 15: "8 Mile"
# Song 16: "8 Mile: 313 Cypher (Chin Tiki Girls)"
# Song 17: "8 Mile Background Music"
# Song 18: "8 Mile: B-Rabbit vs Papa Doc"
# Song 19: "8 Mile: B-Rabbit vs Supa Emcee"
# Song 20: "8 Mile: Cheddar Bob Freestyle"
# Song 21: "8 Mile: D'Phuzion vs B-Rabbit"
# Song 22: "8 Mile: Lily's Lullaby"
# Song 23: "8 Mile: Lotto vs B-Rabbit"
# Song 24: "8 Mile: Lyckety-Splyt vs B-Rabbit"
# Song 25: "8 Mile: Marv Won vs B-Rabbit"
# Song 26: "8 Mile: Maurice Grant vs B-Rabbit"
# Song 27: "8 Mile: Sweet Home Alabama Freestyle"
# Song 28: "8 Mile: The Lunch Truck Battle"
# Song 29: "911"
# Song 30: "'97 Blazer"
# Song 31: "97' Bonnie & Clyde"
# Song 32: "'99 Tim Westwood Freestyle (Unreleased)"
# Song 33: "Almost Famous"
# Song 34: "Amityville"
# Song 35: "Anger Management"
# Song 36: "Anger Management (Turkish Translation)"
# Song 37: "Any Man (Fucking Crazy)"
# Song 38: "Any Word Freestyle"
# Song 39: "Ariel"
# Song 40: "Armaggedon (The Invasion Part 3)"
# Song 41: "Arose"
# Song 42: "Asshole"
# Song 43: "Ass Like That"
# Song 44: "As the World Turns"
# Song 45: "Baby"
# Song 46: "Backstabber"
# Song 47: "Bad Guy"
# Song 48: "Bad Husband"
# Song 49: "Bad Influence"
# Song 50: "Bad Meets Evil"
# Song 51: "Bad Meets Evil Original"
# Song 52: "Bagpipes from Baghdad"
# Song 53: "Ballin' Uncontrollably"
# Song 54: "Baruch College Session"
# Song 55: "Beautiful"
# Song 56: "Beautiful Pain"
# Song 57: "Be Careful What You Wish For"
# Song 58: "Believe"
# "Benzino II (Skit)" does not contain lyrics. Rejecting.
# Song 59: "Berzerk"
# Song 60: "Berzerk Explained"
# Song 61: "Berzerk Single Art"
# Song 62: "BET Shady 2.0 Cypher"
# Song 63: "Big Weenie"
# Song 64: "Bitch Please II"
# "Bitch (Skit)" does not contain lyrics. Rejecting.
# "Bizarre (Skit) [2004]" does not contain lyrics. Rejecting.
# Song 65: "Brain Damage"
# Song 66: "Brain Damage (Snippet)"
# Song 67: "Brainless"
# Song 68: "Breaking News"
# Song 69: "Breaking News - Intro"
# Song 70: "Brenda"
# Song 71: "Broke Day"
# Song 72: "Broken Rubber"
# Song 73: "Buffalo Bill"
# Song 74: "Bully"
# Song 75: "Bump Heads"
# Song 76: "Business"
# Song 77: "Business (Kevin WiRE Remix)"
# Song 78: "Business (Remix)"
# Song 79: "Business Single Art"
# Song 80: "Calm Before the Storm"
# Song 81: "Campaign Speech"
# Song 82: "Cancerous (Freestyle)"
# Song 83: "Can I Bitch (Canibus Diss)"
# Song 84: "Careful What You Wish For"
# Song 85: "Castle"
# Song 86: "Chloraseptic"
# Song 87: "Chloraseptic (Remix)"
# Song 88: "Cinderella Man"
# Song 89: "Cleanin' Out My Closet"
# Song 90: "Cleanin' Out My Closet (Drum & Bass Remix)"
# Song 91: "Cleanin' Out My Closet Single Art"
# Song 92: "C'mon Everybody"
# Song 93: "Cocaine"
# Song 94: "Cock Massage"
# Song 95: "Cold Wind Blows"
# Song 96: "Conglomerate"
# Song 97: "Countdown"
# Song 98: "Crack a Bottle"
# Song 99: "Crack a Bottle (Original Demo)"
# Song 100: "Crackers And Cheese"
# Song 101: "Crazy in Love"
# Song 102: "Criminal"
# Song 103: "Criminal (Snippet)"
# Song 104: "Cum on Everybody"
# "Curtain Call [Tracklist + Album Artwork]" does not contain lyrics. Rejecting.
# "Curtains Close (Skit)" does not contain lyrics. Rejecting.
# Song 105: "Curtains Up [2004]"
# "Curtains Up (Skit)" does not contain lyrics. Rejecting.
# "Curtis (Skit)" does not contain lyrics. Rejecting.
# Song 106: "Déjà Vu"
# Song 107: "Demon Inside"
# Song 108: "Desperation"
# Song 109: "Despicable"
# Song 110: "Detroit vs. Everybody"
# Song 111: "Devil's Night Intro"
# Song 112: "Die Alone"
# Song 113: "Difficult"
# Song 114: "Dirty Steve"
# Song 115: "DJ Fashion Freestyle"
# Song 116: "Doe Rae Me (Hailie's Revenge)"
# Song 117: "Don't Call Me Marshall (Intro)"
# Song 118: "Don't Chew With Your Mouth Full"
# Song 119: "Don't Front"
# Song 120: "Drips"
# Song 121: "Drop It Like It's Hot Freestyle"
# Song 122: "Drop the Bomb on 'Em"
# Song 123: "Drug Ballad"
# "Dr. West (Skit)" does not contain lyrics. Rejecting.
# "Dude (Skit)" does not contain lyrics. Rejecting.
# Song 124: "Elevator"
# Song 125: "Elevator Single Art"
# Song 126: "Em360 Rapcity Backroom Freestyle"
# "Em Calls Paul (Skit) [2004]" does not contain lyrics. Rejecting.
# "Em Calls Paul (Skit) [2018]" does not contain lyrics. Rejecting.
# Song 127: "Eminem DJ Lennox Intro"
# Song 128: "Eminem Freestyle"
# Song 129: "Eminem Freestyle (Hollywood Homicide)"
# Song 130: "Eminem Freestyle On The Farmclub"
# Song 131: "Eminem Interlude"
# Song 132: "Eminem Music Videos"
# Song 133: "Eminem, Paul Rosenberg Intro"
# "Eminem (Skit)" does not contain lyrics. Rejecting.
# Song 134: "Eminem Speaks"
# Song 135: "Eminem's Tattoos"
# Song 136: "Emulate"
# Song 137: "Encore [Artwork]"
# Song 138: "Encore [Booklet]"
# Song 139: "Encore / Curtains Down"
# "ESPN Halftime Booth Interview" does not contain lyrics. Rejecting.
# Song 140: "Everybody's Looking at Me"
# Song 141: "Evil Deeds"
# Song 142: "Evil Twin"
# Song 143: "Facebook Q&A"
# Song 144: "FACK"
# Song 145: "Fall"
# Song 146: "Fallin"
# Song 147: "Farewell"
# "Fat Beats (Skit)" does not contain lyrics. Rejecting.
# Song 148: "Fighterz (Ja Rule Diss)"
# Song 149: "Fight Music Remix"
# "Final Thought (Skit)" does not contain lyrics. Rejecting.
# Song 150: "Fine Line"
# Song 151: "First Word Freestyle"
# Song 152: "Fly Away"
# Song 153: "Food Stamp"
# Song 154: "Foolish Pride"
# Song 155: "Framed"
# Song 156: "Freestyle, Canibus Impression"
# Song 157: "Freestyle gone crazy"
# Song 158: "Freestyle On Tim Westwood"
# Song 159: "Freestyle Power 92.3"
# Song 160: "Fubba U Cubba Cubba"
# Song 161: "Fuck That Shit (Rapture)"
# Song 162: "Fuck You"
# Song 163: "Game Over"
# Song 164: "Get Back Up"
# Song 165: "Get Money"
# "Get Rich or Die Tryin [Tracklist + Album Art]" does not contain lyrics. Rejecting.
# Song 166: "Get You Mad"
# Song 167: "Get You Mad (Türkçe Çeviri)"
# Song 168: "Girls (Limp Bizkit Diss)"
# Song 169: "Give Me The Ball"
# Song 170: "G.O.A.T."
# Song 171: "(God Is) Cleanin' Out My Closet (Religious Remix)"
# "God's Son Album Art" does not contain lyrics. Rejecting.
# Song 172: "Going Through Changes"
# Song 173: "Good Guy"
# Song 174: "Got it Twisted Freestyle"
# Song 175: "Go to Hell Part 2"
# Song 176: "Go to Sleep"
# Song 177: "Greatest"
# Song 178: "Greg"
# Song 179: "Groundhog Day"
# Song 180: "Guilty Conscience"
# Song 181: "Guilty Conscience (Radio Extra Clean W/New Hook)"
# Song 182: "Guilty Conscience Single Art"
# Song 183: "Guilty Conscience (Snippet)"
# Song 184: "Guts Over Fear"
# Song 185: "Guts Over Fear Single Cover Art"
# Song 186: "Hailie's Song"
# Song 187: "Hail Mary"
# Song 188: "Hard"
# Song 189: "Hazardous Youth"
# Song 190: "Headlights"
# Song 191: "Heat"
# Song 192: "Hellbound"
# Song 193: "Hell Breaks Loose"
# Song 194: "Hello"
# "Hell: The Sequel [Tracklist + EP Art]" does not contain lyrics. Rejecting.
# Song 195: "Hit Me With Your Best Shot"
# Song 196: "Hot 100 Chart History"
# Song 197: "I am the nigga"
# Song 198: "Ice Grill You Freestyle"
# "I Decided. [Tracklist + Album Art]" does not contain lyrics. Rejecting.
# Song 199: "If I Had"
# Song 200: "If I Had (Radio Edit)"
# Song 201: "I Kissed a Boy"
# Song 202: "I Live At Home In A Trailer Freestyle"
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             try:  # Python 2.7, use buffering of HTTP responses
# --> 379                 httplib_response = conn.getresponse(buffering=True)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# WantReadError                             Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     276         try:
# --> 277             return self.connection.recv_into(*args, **kwargs)
#     278         except OpenSSL.SSL.SysCallError as e:
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# /anaconda3/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-d4113b6a596f> in <module>
# ----> 1 downloadLyrics(artist_names)
#
# <ipython-input-22-1b685cbd5f54> in downloadLyrics(artist_names, max_songs)
#       1 def downloadLyrics(artist_names, max_songs=None):
# ----> 2     artist_objects = [api.search_artist(name, max_songs=max_songs) for name in artist_names]
#       3     api.save_artists(artist_objects, overwrite=True)
#
# <ipython-input-22-1b685cbd5f54> in <listcomp>(.0)
#       1 def downloadLyrics(artist_names, max_songs=None):
# ----> 2     artist_objects = [api.search_artist(name, max_songs=max_songs) for name in artist_names]
#       3     api.save_artists(artist_objects, overwrite=True)
#
# /anaconda3/lib/python3.6/site-packages/lyricsgenius/api.py in search_artist(self, artist_name, max_songs, get_full_song_info)
#     294                     if song_is_valid:
#     295                         if get_full_song_info:
# --> 296                             song = Song(self.get_song(json_song['id']), lyrics)
#     297                         else:  # Create song with less info (faster)
#     298                             song = Song({'song': json_song}, lyrics)
#
# /anaconda3/lib/python3.6/site-packages/lyricsgenius/api.py in get_song(self, id_)
#      70         """Data for a specific song."""
#      71         endpoint = "songs/{id}".format(id=id_)
# ---> 72         return self._make_request(endpoint)
#      73
#      74     def get_artist(self, id_):
#
# /anaconda3/lib/python3.6/site-packages/lyricsgenius/api.py in _make_request(self, path, method, params_)
#      59             response = self.session.request(method, uri,
#      60                                             timeout=self.timeout,
# ---> 61                                             params=params_)
#      62         except socket.timeout as e:
#      63             print("Timeout raised and caught: {}".format(e))
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     500         }
#     501         send_kwargs.update(settings)
# --> 502         resp = self.send(prep, **send_kwargs)
#     503
#     504         return resp
#
# /anaconda3/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     610
#     611         # Send the request
# --> 612         r = adapter.send(request, **kwargs)
#     613
#     614         # Total elapsed time of the request (approximately)
#
# /anaconda3/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438                     decode_content=False,
#     439                     retries=self.max_retries,
# --> 440                     timeout=timeout
#     441                 )
#     442
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# /anaconda3/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380             except TypeError:  # Python 2.6 and older, Python 3
#     381                 try:
# --> 382                     httplib_response = conn.getresponse()
#     383                 except Exception as e:
#     384                     # Remove the TypeError from the exception chain in Python 3;
#
# /anaconda3/lib/python3.6/http/client.py in getresponse(self)
#    1329         try:
#    1330             try:
# -> 1331                 response.begin()
#    1332             except ConnectionError:
#    1333                 self.close()
#
# /anaconda3/lib/python3.6/http/client.py in begin(self)
#     295         # read until we get a non-100 response
#     296         while True:
# --> 297             version, status, reason = self._read_status()
#     298             if status != CONTINUE:
#     299                 break
#
# /anaconda3/lib/python3.6/http/client.py in _read_status(self)
#     256
#     257     def _read_status(self):
# --> 258         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     259         if len(line) > _MAXLINE:
#     260             raise LineTooLong("status line")
#
# /anaconda3/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /anaconda3/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     287                 raise
#     288         except OpenSSL.SSL.WantReadError:
# --> 289             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     290             if not rd:
#     291                 raise timeout('The read operation timed out')
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/selectors.py in select(self, timeout)
#     511
#     512             kevent_list = _syscall_wrapper(self._kqueue.control, True,
# --> 513                                            None, max_events, timeout)
#     514
#     515             for kevent in kevent_list:
#
# /anaconda3/lib/python3.6/site-packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:
